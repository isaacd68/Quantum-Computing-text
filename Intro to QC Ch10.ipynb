# %% [markdown]
# # **Chapter 10**
# ---
# # Tensor Products

# %% [markdown]
# $V \otimes W$

# %% [markdown]
# ## **10.1** Tensor Product for Quantum Computing

# %% [markdown]
# While *quantum unary gates* are far richer in variety and applicability than *classical unary gates*, there is only so much fun one can have with circuit elements, like

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# which have a single input. We need to combine qubits (a process called *quantum entanglement*), and to do that we'll need gates that have, at a minimum, two inputs,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (You may notice that there are also two outputs, an inevitable consequence of *unitarity* that we'll discuss in this hour.)
#
# In order to feed two qubits into a *binary* quantum gate, we need a new tool to help us calculate, and that tool is the *tensor product* of the two single qubit state spaces
#
# $$
# \mathcal{H} \otimes \mathcal{H}
# $$
#
# The concepts of tensors are no harder to master if we define the general tensor product of *any* two vector spaces, $V$ and $W$ of dimensions $l$ and $m$, respectively,
#
# $$
# V \otimes W
# $$
#
# and this approach will serve us well later in the course. We will then apply what we learn by setting $V=W=\mathcal{H} .$
#
# The tensor product of more than two component spaces like
#
# $$
# V_{0} \otimes V_{1} \otimes V_{2} \otimes \cdots
# $$
#
# or more relevant to us,
#
# $$
# \mathcal{H} \otimes \mathcal{H} \otimes \mathcal{H} \otimes \cdots,
# $$
#
# presents no difficulty once we have mastered the "*sorder 2 tensor*" (product of just two spaces). When we need a product of more than two spaces, as we shall in a future lecture, I'll guide you. For now, let's learn what it means to form the tensor product of just $\text{two}$ vector spaces.

# %% [markdown]
# ## **10.2** The Tensor Product of Two Vector Spaces

# %% [markdown]
# ### **10.2.1** Definitions
# Whenever we construct a new vector space like $V \otimes W$, we need to handle the required equipment. That means
#
# 1. specifying the *scalars* and *vectors*,
#
# 2. defining vector *addition* and *scalar multiplication*, and
#
# 3. confirming all the required *properties*.
#
# **Items 1 and 2** are easy, and we won't be overly compulsive about **item 3**, so it should not be too painful. We'll also want to cover the two - normally optional but for us required - topics,
#
# 4. defining the inner product and
#
# 5. establishing the preferred basis.
#
# If you find this sort of abstraction drudgery, think about the fact that tensors are the requisite pillars of many fields including structural engineering, particle physics and general relativity. Your attention here will not go unrewarded.

# %% [markdown]
# Whenever we construct a new vector space like $V \otimes W$, we need to handle the required equipment. That means
#
# 1. specifying the *scalars* and *vectors*,
#
# 2. defining vector *addition* and *scalar multiplication*, and
#
# 3. confirming all the required *properties*.
#
# **Items 1 and 2** are easy, and we won't be overly compulsive about **item 3**, so it should not be too painful. We'll also want to cover the two - normally optional but for us required - topics,
#
# 4. defining the inner product and
#
# 5. establishing the preferred basis.
#
# If you find this sort of abstraction drudgery, think about the fact that tensors are the requisite pillars of many fields including structural engineering, particle physics and general relativity. Your attention here will not go unrewarded.

# %% [markdown]
# #### Overview

# %% [markdown]
# The new vector space is based on the two vector spaces $V($ dimension $=l)$ and $W$ $($ dimension $=m)$ and is called *tensor product* of $V$ and $W$, written $V \otimes W$. The new space will turn out to have dimension $=l m$, the *product* of the two component space dimensions).

# %% [markdown]
# #### The Scalars of $V \otimes W$

# %% [markdown]
# Both $V$ and $W$ must have a common scalar set in order to form their inner product, and that set will be the scalar set for $V \otimes W$. For *real* vector spaces like $\mathbb{R}^{2}$ and $\mathbb{R}^{3}$, the scalars for

# %% [markdown]
# $$\mathbb{R}^{2} \otimes \mathbb{R}^{3} $$

# %% [markdown]
# would then be $\mathbb{R}$. For the Hilbert spaces of quantum physics (and quantum computing), the scalars are $\mathbb{C}$.

# %% [markdown]
# #### The Vectors in $V \otimes W$

# %% [markdown]
# Vectors of the tensor product space are formed in two stages. I like to Compart"*mental*"-ize them as follows:

# %% [markdown]
# 1. We start by populating $V \otimes W$ with the *formal symbols* $$"\mathbf{v} \otimes \mathbf{w}"$$ consisting of one vector $\mathbf{v}$ from $V$ and another vector $\mathbf{w}$ from $W . \mathbf{v} \otimes \mathbf{w}$ is called the *tensor product* of the two vectors $\mathbf{v}$ and $\mathbf{w}$. There is no way to further merge these two vectors; $\mathbf{v} \otimes \mathbf{w}$ is as concise as their tensor product gets. <br> For example, in the case of $(5,-6)^{t} \in \mathbb{R}^{2}$ and $(\pi, 0,3)^{t} \in \mathbb{R}^{3}$, they provide the tensor product vector $$
# \left(\begin{array}{c}
# 5 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# \pi \\
# 0 \\
# 3
# \end{array}\right) \in \mathbb{R}^{2} \otimes \mathbb{R}^{3}
# $$ with no further simplification possible (notwithstanding the natural basis *coordinate* representation that we will get to, below).
# <br> **Caution**. No one is saying that all these formal products $\mathbf{v} \otimes \mathbf{w}$ are distinct from one another. When we define the *operations*, we'll see there is much duplication.

# %% [markdown]
# 2.   The formal vector products constructed in step 1 produce only a small subset of the tensor product space $V \otimes W$. The most general vector is a finite sum of such symbols.
# <br> The full space $V \otimes W$ consists of all finite sums of the form
# $$
# \begin{gathered}
# \sum_{k} \mathbf{v}_{k} \otimes \mathbf{w}_{k}, \quad \text { with } \\
# \mathbf{v}_{k} \in V \text { and } \mathbf{w}_{k} \in W
# \end{gathered}
# $$
# For example, in the case of the complex vector spaces $V=\mathbb{C}^{3}$ and $W=\mathbb{C}^{4}$, one such typical vector in the "product space" $\mathbb{C}^{3} \otimes \mathbb{C}^{4}$ would be
# $$
# \left(\begin{array}{c}
# 1+i \\
# -6 \\
# 3 i
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# 3 \\
# 4
# \end{array}\right)+\left(\begin{array}{c}
# 1-i \\
# -6 \\
# 3 i
# \end{array}\right) \otimes\left(\begin{array}{c}
# 1-i \\
# \pi \\
# 0 \\
# 0
# \end{array}\right)+\left(\begin{array}{l}
# 2 \\
# 2 \\
# 2
# \end{array}\right) \otimes\left(\begin{array}{c}
# i \\
# i \\
# \sqrt{7} \\
# -i
# \end{array}\right)
# $$
# Although this particular sum can't be further simplified as a combination of separable tensors, we can always simplify long sums so that there are at most $l m$ terms in them. That's because (as we'll learn) there are $l m$ *basis vectors* for the tensor product space. <br> **Second Caution**. Although these sums produce *all* the vectors in $V \otimes W$, they do so many times over. In other words, it will *not* be true that every sum created in this step is a distinct *tensor* from every other *sum*.

# %% [markdown]
# #### Vocabulary

# %% [markdown]
# - **Product Space**. The tensor product of two vector spaces is sometimes referred to as the *product space*.
#
# - **Tensors**. Vectors in the product space are sometimes called *tensors*, emphasizing that they live in the tensor product space of two vector spaces. However, they are still vectors.
#
# - **Separable Tensors**. Those vectors in $V \otimes W$ which arise in the **step 1** are called *separable tensors*; they can be "separated" into two component vectors, one from each space, whose product is the (separable) tensor. **Step 2** presages that most tensors in the product space are not separable. Separable tensors are sometimes called "pure" or "simple".
#
# - **Tensor Product**. We can use the term "tensor product" to mean either the product space or the individual separable tensors. Thus $V \otimes W$ is the *tensor product* of two spaces, while $\mathbf{v} \otimes \mathbf{w}$ is the (separable) *tensor product* of two vectors.

# %% [markdown]
# #### Vector Addition

# %% [markdown]
# This operation is built-into the definition of a tensor; since the general tensor is the sum of separable tensors, adding two of them merely produces another sum, which is automatically a tensor. The twist, if we can call it that, is how we equate those sums which actually represent the same tensor. This all expressed in the following two bullets.
# - For any two tensors,
# $$
# \boldsymbol{\zeta}=\sum_{k} \mathbf{v}_{k} \otimes \mathbf{w}_{k} \quad \boldsymbol{\zeta}^{\prime}=\sum_{j} \mathbf{v}_{j}^{\prime} \otimes \mathbf{w}_{j}^{\prime}
# $$
# their vector sum is the combined sum, i.e.,
# $$
# \zeta+\zeta^{\prime} \equiv \sum_{k} \mathbf{v}_{k} \otimes \mathbf{w}_{k}+\sum_{j} \mathbf{v}_{j}^{\prime} \otimes \mathbf{w}_{j}^{\prime}
# $$
# which simply expresses the fact that a sum of two finite sums is itself a finite sum and therefore agrees with our original definition of a vector object in the product space. The sum may need simplification, but it is a valid object in the product space.
#
# - The tensor product *distributes* over sums in the component space,
# $$
# \begin{aligned}
# &\left(\mathbf{v}+\mathbf{v}^{\prime}\right) \otimes \mathbf{w}=\mathbf{v} \otimes \mathbf{w}+\mathbf{v}^{\prime} \otimes \mathbf{w} \quad \text { and } \\
# &\mathbf{v} \otimes\left(\mathbf{w}+\mathbf{w}^{\prime}\right)=\mathbf{v} \otimes \mathbf{w}+\mathbf{v} \otimes \mathbf{w}^{\prime}
# \end{aligned}
# $$
# Practically, we only need to understand this as a "distributive property," but in theoretical terms it has the effect of producing countless sets of equivalent vectors. That is, it tells how different formal sums in **step 2** of "The Vectors of $\boldsymbol{V} \otimes \boldsymbol{W}^{\prime \prime}$ might represent the same actual tensor.
#
#
# **Commutativity**. Vector addition commutes *by definition*; the formal sums in **step 2** are declared to be *order-independent*.

# %% [markdown]
# #### Scalar Multiplication

# %% [markdown]
# Let $c$ be a scalar. We define its product with a tensor in two steps.
#
# - **$c$ Times a Separable Tensor.**
# $$
# c\left(\mathbf{v}_{0} \otimes \mathbf{w}_{0}+\mathbf{v}_{1} \otimes \mathbf{w}_{1}\right) \equiv c\left(\mathbf{v}_{0} \otimes \mathbf{w}_{0}\right)+c\left(\mathbf{v}_{1} \otimes \mathbf{w}_{1}\right) .
# $$
# Because any tensor can be written as the finite sum of separable tensors, this requirement covers the balance of the product space. You can distribute $c$ over as large a sum as you like.
#
# - **Order.** While we can place $c$ on either the left or right of a vector, it is usually placed on the left, as in ordinary vector spaces.

# %% [markdown]
# #### The Requisite Properties of $V \otimes W$

# %% [markdown]
# Properties like commutative addition, distributivity of scalar multiplication are automatic consequences of the above definitions. I'll leave it as an optional exercise.
#
# > **Exercise**. Prove that $V \otimes W$ satisfies the various operational requirements of a vector space.

# %% [markdown]
# #### Inner Products in $V \otimes W$

# %% [markdown]
# If $V$ and $W$ possess inner products, an inner product is conferred to the product space $V \otimes W$ by
#
# $$
# \left\langle\mathbf{v} \otimes \mathbf{w} \quad \mid \mathbf{v}^{\prime} \otimes \mathbf{w}^{\prime}\right\rangle \quad \equiv\left\langle\mathbf{v} \mid \mathbf{v}^{\prime}\right\rangle \cdot\left\langle\mathbf{w} \mid \mathbf{w}^{\prime}\right\rangle,
# $$
#
# where "." on the RHS is scalar multiplication. This only defines the tensor product of two separable tensors, however we extend this to all tensors by asserting a distributive property (or if you prefer the terminology, by "extending linearly"). For example,
#
# $$
# \begin{aligned}
# &\left\langle\mathbf{v} \otimes \mathbf{w} \mid \mathbf{v}^{\prime} \otimes \mathbf{w}^{\prime}+\mathbf{v}^{\prime \prime} \otimes \mathbf{w}^{\prime \prime}\right\rangle \\
# &\equiv\left\langle\mathbf{v} \otimes \mathbf{w} \mid \mathbf{v}^{\prime} \otimes \mathbf{w}^{\prime}\right\rangle+\left\langle\mathbf{v} \otimes \mathbf{w} \quad \mid \mathbf{v}^{\prime \prime} \otimes \mathbf{w}^{\prime \prime}\right\rangle
# \end{aligned}
# $$

# %% [markdown]
# > **Exercise**. Compute the inner product in $\mathbb{R}^{2} \otimes \mathbb{R}^{3}$
# $$
# \left.\left.\left.\left\langle\left(\begin{array}{c}
# 5 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# \pi \\
# 0 \\
# 3
# \end{array}\right)\right| \quad\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# 3
# \end{array}\right)\right.\right\rangle\right]$$
#
# > **Exercise**. Compute the inner product in $\mathbb{C}^{3} \otimes \mathbb{C}^{4}$
# $$
# \left.\left\langle\left(\begin{array}{c}
# 1+i \\
# -6 \\
# 3 i
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# 3 \\
# 4
# \end{array}\right)+\left(\begin{array}{c}
# -i \\
# -6 \\
# 3 i
# \end{array}\right) \otimes\left(\begin{array}{l}
# i \\
# \pi \\
# 0 \\
# 1
# \end{array}\right) |\left(\begin{array}{l}
# 1 \\
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# i \\
# 1 \\
# i
# \end{array}\right)\right\rangle\right]
# $$
#
# > Exercise. Prove that the definition of inner product satisfies all the usual requirements or a dot or inner product. Be sure to cover *distributivity* and *positive definiteness*.

# %% [markdown]
# #### The Natural Basis for $V \otimes W$

# %% [markdown]
# Of all the aspects of tensor products, the one that we will use most frequently is the preferred basis.

# %% [markdown]
# ##### **Tensor Product Basis Theorem (Orthonormal Version)**.

# %% [markdown]
# *If $V$ has dimension $l$ with orthonormal basis*
# $$
# \left\{\mathbf{v}_{k}\right\}_{k=0}^{l-1}
# $$
# *and $W$ has dimension $m$, with orthonormal basis*
# $$
# \left\{\mathbf{w}_{j}\right\}_{j=0}^{m-1}
# $$
# *then $V \otimes W$ has dimension lm and "inherits" a natural (preferred) orthonormal basis*
# $$
# \left\{\mathbf{v}_{k} \otimes \mathbf{w}_{j}\right\}_{j, k=0,0}^{l-1, m-1}
# $$
# *from $V$ and $W$. For example, the natural basis for $\mathbb{R}^{2} \otimes \mathbb{R}^{3}$ is*
# $$
# \begin{gathered}
# \left\{\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 0 \\
# 0
# \end{array}\right),\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right),\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 0 \\
# 1
# \end{array}\right)\right. \\
# \left.\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 0 \\
# 0
# \end{array}\right),\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right),\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 0 \\
# 1
# \end{array}\right)\right\}
# \end{gathered}
# $$

# %% [markdown]
# ###### **Proof of Basis Theorem.**
#  I'll guide you through the proof, and you can fill in the gaps as an exercise if you care to.
#
# **Spanning**. A basis must span the space. We need to show that any tensor can be expressed as a linear combination of the alleged basis vectors $\mathbf{v}_{k} \otimes \mathbf{w}_{j}$. This is an easy two parter:
#
# 1. Any $\mathbf{v} \in V$ can be expanded along the $V$ - basis as
# $$
# \mathbf{v}=\sum \alpha_{k} \mathbf{v}_{k}
# $$
# and any $\mathbf{w} \in W$ can be expanded along the $W$ - basis as
# $$
# \mathbf{w}=\sum \beta_{j} \mathbf{w}_{j}
# $$
# which implies that any separable tensor $\mathbf{v} \otimes \mathbf{w}$ can be expressed
# $$
# \mathbf{v} \otimes \mathbf{w}=\sum \alpha_{k} \beta_{j}\left(\mathbf{v}_{k} \otimes \mathbf{w}_{j}\right)
# $$
# > **Exercise**. Prove the last identity by applying linearity (distributive properties of the tensor product space).
#
# 2. Any tensor is a sum of separable tensors, so item 1 tells us that it, too, can be expressed as a linear combination of $\mathbf{v}_{k} \otimes \mathbf{w}_{j} .$
# > **Exercise**. Demonstrate this algebraically.

# %% [markdown]
# ##### **Linear Independence and Orthonormality.**
# We rely on a little theorem to which I subjected you *twice*, first in the linear algebra lecture, then again in the Hilbert space lecture. It said that an *orthonormality* $\Rightarrow$ *linearly independence*. We now show that the set $\left\{\mathbf{v}_{k} \otimes \mathbf{w}_{j}\right\}$ is orthonormal collection of vectors.
# $$
# \begin{aligned}
# \left\langle\mathbf{v}_{k} \otimes \mathbf{w}_{j} \mid \mathbf{v}_{k^{\prime}} \otimes \mathbf{w}_{j^{\prime}}\right\rangle &=\left\langle\mathbf{v}_{k} \mid \mathbf{v}_{k^{\prime}}\right\rangle\left\langle\mathbf{w}_{j} \mid \mathbf{w}_{j^{\prime}}\right\rangle \\
# &= \begin{cases}1, & \text { if } k=k^{\prime} \text { and } j=j^{\prime} \\
# 0, & \text { otherwise }\end{cases}
# \end{aligned}
# $$
# This is the definition of orthonormality, so by our little theorem the vectors in $\left\{\mathbf{v}_{k} \otimes \mathbf{w}_{j}\right\}$ are linearly independent. $QED$
#
# The basis theorem works even if the component bases are not orthonormal. Of course, in that case, the inherited tensor basis is not orthonormal.
#
# > **Tensor Product Basis Theorem (General Version)**.
# *If $V$ has dimension $l$ with basis*
# $$
# \left\{\mathbf{v}_{k}\right\}_{k=0}^{l-1}
# $$
# *and $W$ has dimension $\mathrm{m}$, with basis*
# $$
# \left\{\mathbf{w}_{j}\right\}_{j=0}^{m-1}
# $$
# *then $V \otimes W$ has dimension $l \mathrm{~m}$ and "inherits" a natural (preferred) basis*
# $$
# \left\{\mathbf{v}_{k} \otimes \mathbf{w}_{j}\right\}_{j, k=0,0}^{l-1, m-1}
# $$
# *from $V$ and $W$.*
#
# If $V$ and $W$ each have an inner product (true for any of our vector spaces) this theorem follows immediately from the orthonormal basis theorem.
#
# > **Exercise**. Give a one sentence proof of this theorem based on the orthonormal product basis theorem.
#
# The theorem is still true, even if the two spaces don't have inner products, but we won't bother with that version.

# %% [markdown]
# #### Practical Summary of the Tensor Product Space

# %% [markdown]
# While we have outlined a rigorous construction for a tensor product space, it is usually good enough for computer scientists to characterize the produce space in terms of the tensor basis.
#
# The produce space, $U=V \otimes W$ consists of tensors, $\mathbf{u}$, expressible as sums of the *separable basis*
#
# $$
# \left\{\mathbf{v}_{k} \otimes \mathbf{w}_{j} \mid j=0, \ldots,(n-1), \quad k=0, \ldots,(m-1)\right\}
# $$
#
# weighted by *scalar* weights $c_{k j}$,
#
# $$
# \mathbf{u}=\sum_{k=0 \atop j=0}^{(n-1)(m-1)} c_{k j}\left(\mathbf{v}_{k} \otimes \mathbf{w}_{j}\right)
# $$
#
# The $n m$ basis tensors, $\mathbf{v}_{k} \otimes \mathbf{w}_{j}$, are induced by the two component bases,
#
# $$
# \begin{aligned}
# \mathcal{V} &=\left\{\mathbf{v}_{k}\right\}_{k=0}^{n-1} \quad \text { and } \\
# \mathcal{W} &=\left\{\mathbf{w}_{j}\right\}_{j=0}^{m-1}
# \end{aligned}
# $$
#
# The *sums*, *products* and *equivalence* of tensor expressions are defined by the required *distributive* and *commutative* properties listed earlier, but can often be taken as the natural rules one would expect.

# %% [markdown]
# #### Conventional Order of Tensor Basis

# %% [markdown]
# While not universal, when we need to list the tensor basis linearly, the most common convention is to let the left basis index increment slowly and the right increment quickly. It is " $V$-major $/ W$-minor format" if you will, an echo of the row-major ( column-minor) ordering choice of arrays in computer science,
#
# $$
# \begin{array}{ll}
# \left\{\mathbf{v}_{0} \otimes \mathbf{w}_{0}, \quad \mathbf{v}_{0} \otimes \mathbf{w}_{1},\right. & \mathbf{v}_{0} \otimes \mathbf{w}_{2}, \quad \ldots, \quad \mathbf{v}_{0} \otimes \mathbf{w}_{m-1} \\
# & \mathbf{v}_{1} \otimes \mathbf{w}_{0}, \mathbf{v}_{1} \otimes \mathbf{w}_{1}, \quad \mathbf{v}_{1} \otimes \mathbf{w}_{2}, \ldots, \quad \mathbf{v}_{1} \otimes \mathbf{w}_{m-1}, \\
# & \ddots \\
# & \left.\mathbf{v}_{l-1} \otimes \mathbf{w}_{0}, \quad \mathbf{v}_{l-1} \otimes \mathbf{w}_{1}, \quad \mathbf{v}_{l-1} \otimes \mathbf{w}_{2}, \mathbf{v}_{l-1} \otimes \mathbf{w}_{m-1}\right\}
# \end{array}
# $$
#
# You might even see these basis tensors labeled using the shorthand like $\zeta_{k j}$,
#
# $$
# \begin{array}{ll}
# \left\{\zeta_{00}, \quad \zeta_{01},\right. & \zeta_{02}, \ldots, \zeta_{0(m-1)} \\
# \zeta_{10}, & \zeta_{11}, \quad \zeta_{12}, \ldots, \quad \zeta_{1(m-1)}, \\
# & \ddots \\
# \quad & \left.\zeta_{(l-1) 0}, \quad \zeta_{(l-1) 1}, \quad \zeta_{(l-1) 2}, \ldots, \quad \zeta_{(l-1)(m-1)}\right\}
# \end{array}
# $$

# %% [markdown]
# ### **10.2.2** Tensor Coordinates from Component-Space Coordinates

# %% [markdown]
# We have defined everything relating to a tensor product space $V \otimes W$. Before we apply that to qubits, we must make sure we can quickly write down coordinates of a tensor in the preferred (natural) basis. This starts, as always, with (i) separable tensors, from which we move to the (ii) basis tensors, and finally graduate to (iii) general tensors.

# %% [markdown]
# #### Natural Coordinates of Separable Tensors

# %% [markdown]
# We are looking for the coordinates of a pure tensor, expressible as a product of two component vectors whose preferred coordinates we already know,
#
# $$
# \mathbf{v} \otimes \mathbf{w}=\left(\begin{array}{c}
# c_{0} \\
# c_{1} \\
# \vdots \\
# c_{l-1}
# \end{array}\right) \otimes\left(\begin{array}{c}
# d_{0} \\
# d_{1} \\
# \vdots \\
# d_{m-1}
# \end{array}\right)
# $$
#
# > **A Reminder**. We are numbering staring with 0, rather than 1, now that we are in computing lessons.
#
# I'm going to give you the answer immediately, and allow you to skip the explanation if you are in a hurry.
#
# $$
# \left(\begin{array}{c}
# c_{0} \\
# c_{1} \\
# \vdots \\
# c_{l-1}
# \end{array}\right) \otimes\left(\begin{array}{c}
# d_{0} \\
# d_{1} \\
# \vdots \\
# d_{m-1}
# \end{array}\right)=
# \begin{pmatrix}
# c_{0}\left(\begin{array}{c}
# d_{0} \\
# d_{1} \\
# \vdots \\
# d_{m-1}
# \end{array}\right) \\
# c_{1}\left(\begin{array}{c}
# d_{0} \\
# d_{1} \\
# \vdots \\
# d_{m-1}
# \end{array}\right) \\
# \vdots \\
# c_{l-1}\left(\begin{array}{c}
# d_{0} \\
# d_{1} \\
# \vdots \\
# d_{m-1}
# \end{array}\right)
# \end{pmatrix} =
# \begin{pmatrix}
# c_{0} d_{0} \\
# c_{0} d_{1} \\
# \vdots \\
# c_{0} d_{m-1} \\
# c_{1} d_{0} \\
# c_{0} d_{1} \\
# \vdots \\
# c_{1} d_{m-1} \\
# c_{2} d_{0} \\
# c_{2} d_{1} \\
# \vdots \\
# c_{2} d_{m-1} \\
# . \\
# . \\
# . \\
# c_{l-1} d_{0} \\
# c_{l-1} d_{1} \\
# \vdots \\
# c_{l-1} d_{m-1} \\
# \end{pmatrix}
# $$

# %% [markdown]
# **Example**. For $(5,-6)^{t} \in \mathbb{R}^{2}$ and $(\pi, 0,3)^{t} \in \mathbb{R}^{3}$, their tensor product in $\mathbb{R}^{2} \otimes \mathbb{R}^{3}$ has natural basis coordinates given by
# $$
# \left(\begin{array}{c}
# 5 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# \pi \\
# 0 \\
# 3
# \end{array}\right)=\left(\begin{array}{c}
# 5 \pi \\
# 0 \\
# 15 \\
# -6 \pi \\
# 0 \\
# -18
# \end{array}\right)
# $$

# %% [markdown]
# > **Exercise**. Give the coordinate representation of the following tensor in the natural tensor basis.
# $$
# \left(\begin{array}{c}
# 1+i \\
# -6 \\
# 3 i
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# 3 \\
# 4
# \end{array}\right)
# $$

# %% [markdown]
# **Explanation.** I'll demonstrate the validity of the formula in the special case $\mathbb{R}^{2} \otimes \mathbb{R}^{3}$. The derivation will work for any $V$ and $W$ (as the upcoming exercise shows).
#
# Consider the tensor product of two general vectors,
# $$
# \left(\begin{array}{l}
# c_{0} \\
# c_{1}
# \end{array}\right) \otimes\left(\begin{array}{l}
# d_{0} \\
# d_{1} \\
# d_{2}
# \end{array}\right)
# $$
# Let's zoom in on the meaning of each column vector which is, after all, shorthand notation for the following,
# $$
# \left[c_{0}\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right)+c_{1}\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right)\right] \otimes\left[d_{0}\left(\begin{array}{l}
# 1 \\
# 0 \\
# 0
# \end{array}\right)+d_{1}\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)+d_{2}\left(\begin{array}{l}
# 0 \\
# 0 \\
# 1
# \end{array}\right)\right]
# $$
# Now apply the linearity to equate the above with
# $$
# \begin{gathered}
# c_{0} d_{0}\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 0 \\
# 0
# \end{array}\right)+c_{0} d_{1}\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)+c_{0} d_{2}\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 0 \\
# 1
# \end{array}\right) \\
# +c_{1} d_{0}\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 0 \\
# 0
# \end{array}\right)+c_{1} d_{1}\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)+c_{1} d_{2}\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 0 \\
# 1
# \end{array}\right)
# \end{gathered}
# $$
# Next, identify each of the basis tensor products with their symbolic $\mathbf{v}_{k}$ (for $\mathbb{R}^{2}$ ) and $\mathbf{w}_{j}\left(\right.$ for $\left.\mathbb{R}^{3}\right)$ to see it more clearly,
# $$
# \begin{aligned}
# & c_{0} d_{0}\left(\mathbf{v}_{0} \otimes \mathbf{w}_{0}\right)+c_{0} d_{1}\left(\mathbf{v}_{0} \otimes \mathbf{w}_{1}\right)+c_{0} d_{2}\left(\mathbf{v}_{0} \otimes \mathbf{w}_{2}\right) \\
# +\quad & c_{1} d_{0}\left(\mathbf{v}_{1} \otimes \mathbf{w}_{0}\right)+c_{1} d_{1}\left(\mathbf{v}_{1} \otimes \mathbf{w}_{1}\right)+c_{1} d_{2}\left(\mathbf{v}_{1} \otimes \mathbf{w}_{2}\right) .
# \end{aligned}
# $$
# The basis tensors are listed in the conventional ("V-major / $W$-minor format") allowing us to write down the coordinates of the tensor,
# $$
# \left(\begin{array}{l}
# c_{0} d_{0} \\
# c_{0} d_{1} \\
# c_{0} d_{2} \\
# c_{1} d_{0} \\
# c_{1} d_{1} \\
# c_{1} d_{2}
# \end{array}\right)
# $$
# as claimed. $QED$
#
# > **Exercise**. Replicate the demonstration for the coordinates of a separable tensor $\mathbf{v} \otimes \mathbf{w}$ in any product space $\mathbf{V} \otimes \mathbf{W}$.

# %% [markdown]
# #### Natural Coordinates of Basis Tensors

# %% [markdown]
# By definition and a previous exercise (see the lecture on linear transformations) we know that each basis vector, $\mathbf{b}_{k}$, when expressed in its own $\mathcal{B}$-coordinates looks exactly like the $k$ th preferred basis element, i.e.,
#
# $$
# \left.\mathbf{b}_{k}\right|_{\mathcal{B}}=\left(\begin{array}{c}
# 0 \\
# \vdots \\
# 1 \\
# \vdots \\
# 0
# \end{array}\right) \longleftarrow k \text { th element }
# $$
#
# The is true for our tensor basis, which means that once we embrace that basis, we have $l m$ basis vectors
#
# $$
# \left.\left(\begin{array}{c}
# 1 \\
# \vdots \\
# 0 \\
# \vdots \\
# 0
# \end{array}\right), \quad \cdots, \quad\left(\begin{array}{c}
# 0 \\
# \vdots \\
# 1 \\
# \vdots \\
# 0
# \end{array}\right), \quad \cdots, \quad\left(\begin{array}{c}
# 0 \\
# \vdots \\
# 0 \\
# \vdots \\
# 1
# \end{array}\right)\right\} \operatorname{lm}
# $$
#
# which don't make reference to the two component vector spaces or the inherited $V$ major $/ W$-minor ordering we decided to use. However, for this to be useful, we need an implied correspondence between these vectors and the inherited basis
#
# $$
# \begin{array}{ll}
# \left\{\mathbf{v}_{0} \otimes \mathbf{w}_{0}, \quad \mathbf{v}_{0} \otimes \mathbf{w}_{1},\right. & \mathbf{v}_{0} \otimes \mathbf{w}_{2}, \quad \ldots, \quad \mathbf{v}_{0} \otimes \mathbf{w}_{m-1} \\
# & \mathbf{v}_{1} \otimes \mathbf{w}_{0}, & \mathbf{v}_{1} \otimes \mathbf{w}_{1}, \quad \mathbf{v}_{1} \otimes \mathbf{w}_{2}, \ldots, \quad \mathbf{v}_{1} \otimes \mathbf{w}_{m-1} \\
# & \cdot \\
# & \left.\mathbf{v}_{l-1} \otimes \mathbf{w}_{0}, \quad \mathbf{v}_{l-1} \otimes \mathbf{w}_{1}, \quad \mathbf{v}_{l-1} \otimes \mathbf{w}_{2}, \mathbf{v}_{l-1} \otimes \mathbf{w}_{m-1}\right\}
# \end{array}
# $$
#
# This is all fine, as long as we remember that those self-referential tensor bases assume some agreed-upon ordering system, and in this course that will be the $V$-major ordering.
#
# To illustrate this, say we are working with the basis vector
#
# $$
# \left(\begin{array}{l}
# 0 \\
# 0 \\
# 0 \\
# 0 \\
# 1 \\
# 0
# \end{array}\right) \in \mathbb{R}^{2} \otimes \mathbb{R}^{3}
# $$
#
# In the rare times when we need to relate this back to our original vector spaces we would count: The 1 is in position 4 (counting from 0 ), and relative to $\mathbb{R}^{2}$ and $\mathbb{R}^{3}$ this means
#
# $$
# 4=1 \times 3+1,
# $$
#
# yielding the individual basis vectors $\# \mathbf{1}$ in $V$ and $\# \mathbf{1}$ in $W$. Therefore, the correspondence is
#
# $$
# \left(\begin{array}{l}
# 0 \\
# 0 \\
# 0 \\
# 0 \\
# 1 \\
# 0
# \end{array}\right) \longleftrightarrow \mathbf{v}_{1} \otimes \mathbf{w}_{1}=\left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)
# $$
#
# which we can confirm by multiplying out the RHS as we learned in the last section
#
# $$
# \left(\begin{array}{l}
# 0 \\
# 1
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 0
# \end{array}\right)=\left(\begin{array}{l}
# 0 \cdot 0 \\
# 0 \cdot 1 \\
# 0 \cdot 0 \\
# 1 \cdot 0 \\
# 1 \cdot 1 \\
# 1 \cdot 0
# \end{array}\right) \quad=\left(\begin{array}{l}
# 0 \\
# 0 \\
# 0 \\
# 0 \\
# 1 \\
# 0
# \end{array}\right)
# $$
#
# This will be easy enough with our 2 -dimensional component spaces $\mathcal{H}$, but if you aren't prepared for it, you might find yourself drifting aimlessly when faced with a long column basis tensor and don't know what to do with it.

# %% [markdown]
# #### Natural Coordinates of General Tensors

# %% [markdown]
# Because the tensor space has dimension $l m$, we know that any tensor in the natural basis will look like
#
# $$
# \left(\begin{array}{c}
# \zeta_{0} \\
# \zeta_{1} \\
# \zeta_{2} \\
# \vdots \\
# \zeta_{l m-2} \\
# \zeta_{l m-1}
# \end{array}\right)
# $$
#
# The only thing worth noting here is the correspondence between this and the component spaces $V$ and $W$. If we are lucky enough to have a separable tensor in our hands, this would have the special form
#
# and we might be able to figure out the component vectors from this. However, in general, we don't have separable tensors. All we can say is that this tensor is a linear combination of the $l m$ basis vectors, and just accept that it has the somewhat random components, $\zeta_{i}$ which we might label simply
#
# $$
# \left(\begin{array}{c}
# \zeta_{0} \\
# \zeta_{1} \\
# \zeta_{2} \\
# \vdots \\
# \zeta_{l m-2} \\
# \zeta_{l m-1}
# \end{array}\right)
# $$
#
# or we might label with an eye on our component spaces
#
# $$
# \left(\begin{array}{c}
# \zeta_{00} \\
# \zeta_{01} \\
# \zeta_{02} \\
# \vdots \\
# \zeta_{0(m-1)} \\
# \hline \zeta_{10} \\
# \zeta_{11} \\
# \zeta_{12} \\
# \vdots \\
# \zeta_{1(m-1)} \\
# \hline \zeta_{20} \\
# \zeta_{21} \\
# \zeta_{22} \\
# \vdots \\
# \zeta_{2(m-1)} \\
# \vdots
# \end{array}\right)
# $$
#
# with the awareness that these components $\zeta_{k j}$ may not be products of two factors $c_{k} d_{j}$ originating in two vectors $\left(c_{0}, \ldots, c_{l-1}\right)^{t}$ and $\left(d_{0}, \ldots, d_{m-1}\right)^{t}$.
#
# One thing we do know: Any tensor can be written as a weighted-sum of, at most, $l m$ separable tensors. (If this is not immediately obvious, please review the tensor product basis theorem.)

# %% [markdown]
# **Example**. Let's compute the coordinates of the non-separable tensor
#
# $$
# \zeta=\left(\begin{array}{c}
# 3 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# \pi
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 1
# \end{array}\right)
# $$
#
# in the natural basis. We do it by applying the above formula to each separable component and adding,
#
# $$
# \zeta=\left(\begin{array}{c}
# 3\left(\begin{array}{c}
# 1 \\
# 2 \\
# \pi
# \end{array}\right) \\
# -6\left(\begin{array}{l}
# 1 \\
# 2 \\
# \pi
# \end{array}\right)
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0 & \left(\begin{array}{l}
# 0 \\
# 1 \\
# 1
# \end{array}\right) \\
# 0 & \left(\begin{array}{l}
# 0 \\
# 1 \\
# 1
# \end{array}\right)
# \end{array}\right)=\left(\begin{array}{c}
# 3 \\
# 6 \\
# 3 \pi \\
# -6 \\
# -12 \\
# -6 \pi
# \end{array}\right)+\left(\begin{array}{c}
# 0 \\
# 1 \\
# 1 \\
# 0 \\
# 0 \\
# 0
# \end{array}\right)=\left(\begin{array}{c}
# 3 \\
# 7 \\
# 1+3 \pi \\
# -6 \\
# -12 \\
# -6 \pi
# \end{array}\right)
# $$

# %% [markdown]
# #### Tensors as Matrices

# %% [markdown]
# If the two component spaces have dimension $l$ and $m$, we know that the product space has dimension $l \mathrm{~m}$. More recently we've been talking about how these $l \mathrm{~m}$ coordinates might be organized. Separable or not, a tensor is completely determined by its $l m$ preferred coefficients, which suggests a rectangle of numbers,
#
# $$
# \left(\begin{array}{ccccc}
# \zeta_{00} & \zeta_{01} & \zeta_{02} & \cdots & \zeta_{0(m-1)} \\
# \zeta_{10} & \zeta_{11} & \zeta_{12} & \cdots & \zeta_{1(m-1)} \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# \zeta_{(l-1) 0} & \zeta_{(l-1) 1} & \zeta(l-1) 2 & \cdots & \zeta_{(l-1)(m-1)}
# \end{array}\right)
# $$
#
# which happens to have a more organized structure in the separable case,
#
# $$
# \left(\begin{array}{ccccc}
# c_{0} d_{0} & c_{0} d_{1} & c_{0} d_{2} & \cdots & c_{0} d_{m-1} \\
# c_{1} d_{0} & c_{1} d_{1} & c_{1} d_{2} & \cdots & c_{1} d_{m-1} \\
# \vdots & \vdots & \vdots & \ddots & \vdots \\
# c_{l-1} d_{0} & c_{l-1} d_{1} & c_{l-1} d_{2} & \cdots & c_{l-1} d_{m-1}
# \end{array}\right)
# $$
#
# This matrix is not to be interpreted as a linear transformation of either component space $-$ it is just a vector in the product space. (It *does* have a meaning as scalarvalued function, but we'll leave that as a topic for courses in relativity, particle physics or structural engineering.)
#
# Sometimes the $l m$ *column vector model* serves tensor imagery best, while other times the $l \times m$ *matrix* model works better. It's good to be ready to use either one as the situation demands.

# %% [markdown]
# ## **10.3** Linear Operators on the Tensor Product Space

# %% [markdown]
# The product space is a *vector space*, and as such supports *linear transformations*. Everything we know about them applies here: they have *matrix representations* in the natural basis, some are *unitary*, some not, some are *Hermitian*, some not, some have *inverses*, some don't, etc. The only special and new topic that confronts us is how the linear transformation of the two component spaces, $V$ and $W$, inform those of the product space, $V \otimes W$.
#
# The situation will feel familiar. Just as tensors in $V \otimes W$ fall into two main classes, those that are *separable* (products, $\mathbf{v} \otimes \mathbf{w}$, of two vectors) and those that aren't (they are built from sums of separable tensors), the *operators* on $V \otimes W$ have a corresponding breakdown.

# %% [markdown]
# ### **10.3.1** Separable Operators

# %% [markdown]
# If $A$ is a linear transformation (a.k.a. an "operator") on $V$
#
# $$
# A: V \longrightarrow V
# $$
#
# and $B$ is a linear transformation on $W$
#
# $$
# B: W \longrightarrow W,
# $$
#
# then their *tensor product*, $A \otimes B$ is a linear transformation on the product space $V \otimes W$
#
# $$
# A \otimes B: V \otimes W \longrightarrow V \otimes W \text {, }
# $$
#
# defined by its action on the separable tensors
#
# $$
# [A \otimes B](\mathbf{v} \otimes \mathbf{w}) \equiv A \mathbf{v} \otimes B \mathbf{w}
# $$
#
# and extended to general tensors linearly.
#
# - **Note 1**: We could have defined $A \otimes B$ first on just the $l m$ basis vectors $\mathbf{v}_{k} \otimes \mathbf{w}_{j}$, since they span the space. However, it's so useful to remember that we can use this formula on any two component vectors $\mathbf{v}$ and $\mathbf{w}$, that I prefer to make this the official definition.
#
# - **Note 2**: $A$ and/or $B$ need not map their respective vector spaces into themselves. For example, perhaps $A: V \mapsto V^{\prime}$ and $B: W \mapsto W^{\prime}$. Then $A \otimes B: V \otimes W \mapsto V^{\prime} \otimes W^{\prime}$. However, we will usually encounter the simpler case covered by the definition above. <br>
# $\quad$ One must verify that this results in a linear transformation (operator) on the product space by proving that for an $\zeta, \boldsymbol{\eta} \in V \otimes W$ and scalar $c$,
# $$
# \begin{aligned}
# [A \otimes B](\zeta+\boldsymbol{\eta}) &=[A \otimes B] \zeta+[A \otimes B] \boldsymbol{\eta} \quad \text { and } \\
# [A \otimes B](c \boldsymbol{\zeta}) &=c[A \otimes B] \zeta
# \end{aligned}
# $$
#
# This is very easy to do as an...
# > **Exercise**. Prove this by first verifiying it on separable tensors then showing that the extension to general tensors preserves the properties.

# %% [markdown]
# **Example**. Let $A$ be defined on $\mathbb{R}^{2}$ by
#
# $$
# A \mathbf{v}=A\left(\begin{array}{l}
# v_{0} \\
# v_{1}
# \end{array}\right) \equiv\left(\begin{array}{c}
# v_{0}+2 v_{1} \\
# v_{1}
# \end{array}\right)
# $$
#
# and $B$ be defined on $\mathbb{R}^{3}$ by
#
# $$
# B \mathbf{w} \equiv \pi \mathbf{w}=\left(\begin{array}{l}
# \pi w_{0} \\
# \pi w_{1} \\
# \pi w_{2}
# \end{array}\right)
# $$
#
# On separable tensors, then, $A \otimes B$ has the effect expressed by
#
# $$
# [A \otimes B](\mathbf{v} \otimes \mathbf{w})=\left(\begin{array}{c}
# v_{0}+2 v_{1} \\
# v_{1}
# \end{array}\right) \otimes\left(\begin{array}{l}
# \pi w_{0} \\
# \pi w_{1} \\
# \pi w_{2}
# \end{array}\right)
# $$
#
# and this is extended linearly to general tensors. To get specific, we apply $A \otimes B$ to the tensor
#
# $$
# \zeta=\left(\begin{array}{c}
# 3 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# \pi
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 1
# \end{array}\right)
# $$
#
# to get
#
# $$
# \begin{aligned}
# [A \otimes B] \zeta &=\left(\begin{array}{c}
# 3+(-12) \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{c}
# \pi \\
# 2 \pi \\
# \pi^{2}
# \end{array}\right)+\left(\begin{array}{c}
# 1+0 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# \pi \\
# \pi
# \end{array}\right) \\
# &=\left(\begin{array}{c}
# -9 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{c}
# \pi \\
# 2 \pi \\
# \pi^{2}
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# \pi \\
# \pi
# \end{array}\right)
# \end{aligned}
# $$
#
# with no simplification obvious. However, an equivalent expression can be formed by extracting a factor of $\pi$ :
#
# $$
# [A \otimes B] \zeta=\pi\left[\left(\begin{array}{l}
# -9 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# \pi
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 1
# \end{array}\right)\right]
# $$
#
# We can always forsake the separable components and instead express this as a column vector in the product space by adding the two separable tensors,
#
# $$
# \begin{gathered}
# {[A \otimes B] \zeta=\left(\begin{array}{c}
# -9 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{c}
# \pi \\
# 2 \pi \\
# \pi^{2}
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{c}
# 0 \\
# \pi \\
# \pi
# \end{array}\right)} \\
# =\left(\begin{array}{c}
# -9 \pi \\
# -18 \pi \\
# -9 \pi^{2} \\
# -6 \pi \\
# -12 \pi \\
# -6 \pi^{2}
# \end{array}\right)+\left(\begin{array}{c}
# 0 \\
# \pi \\
# \pi \\
# 0 \\
# 0 \\
# 0
# \end{array}\right)=\left(\begin{array}{c}
# -9 \pi \\
# -17 \pi \\
# \pi-9 \pi^{2} \\
# -6 \pi \\
# -12 \pi \\
# -6 \pi^{2}
# \end{array}\right)
# \end{gathered}
# $$

# %% [markdown]
# ### **10.3.2** The Matrix of a Separable Operator

# %% [markdown]
# We can write down the matrix for any separable operator using a method very similar to that used to produce the coordinate representation of a separable tensor product of vectors. As you recall, we used a $V$-*major format* which multiplied the entire vector $\mathrm{w}$ by each coordinate of $\mathbf{v}$ to build the result. The same will work here. We use an A-*major format*, i.e., the left operator's coordinates change more "slowly" than the right operator's. Stated differently, we multiply each element of the left matrix by the entire matrix on the right.
#
# $$
# \left.\begin{array}{c}
# \left(\begin{array}{cccc}
# a_{00} & a_{01} & \cdots & a_{0(l-1)} \\
# a_{10} & a_{11} & \cdots & a_{1(l-1)} \\
# \vdots & \vdots & \ddots & \vdots
# \end{array}\right) \otimes\left(\begin{array}{cccc}
# b_{00} & b_{01} & \cdots & b_{0(m-1)} \\
# b_{10} & b_{11} & \cdots & b_{1(m-1)} \\
# \vdots & \vdots & \ddots & \vdots
# \end{array}\right) \\
# =
# \begin{pmatrix}
# a_{00}\left(\begin{array}{ccc}
# b_{00} & b_{01} & \cdots \\
# b_{10} & b_{11} & \cdots \\
# \vdots & \vdots & \ddots
# \end{array}\right) &
# a_{01}\left(\begin{array}{ccc}
# b_{00} & b_{01} & \cdots \\
# b_{10} & b_{11} & \cdots \\
# \vdots & \vdots & \ddots
# \end{array}\right) &
# \cdots \\
# a_{10}\left(\begin{array}{ccc}
# b_{00} & b_{01} & \cdots \\
# b_{10} & b_{11} & \cdots \\
# \vdots & \vdots & \ddots
# \end{array}\right) &
# a_{11}\left(\begin{array}{ccc}
# b_{00} & b_{01} & \cdots \\
# b_{10} & b_{11} & \cdots \\
# \vdots & \vdots & \ddots
# \end{array}\right) &
# \cdots \\
# \vdots & \vdots & \ddots
# \end{pmatrix}
# \end{array}\right.
# $$
#
# This works based on a $V$-major column format for the vectors in the product space. If we had used a $W$-major column format, then we would have had to define the product matrix using a $B$-major rule rather than the A-major rule given above.

# %% [markdown]
# **Example**. The matrices for the $A$ and $B$ of our last example are given by
#
# $$
# A=\left(\begin{array}{ll}
# 1 & 2 \\
# 0 & 1
# \end{array}\right) \text { and } B=\left(\begin{array}{ccc}
# \pi & 0 & 0 \\
# 0 & \pi & 0 \\
# 0 & 0 & \pi
# \end{array}\right)
# $$
#
# so the tensor product transformation $A \otimes B$ is immediately written down as
#
# $$
# A \otimes B=\left(\begin{array}{cccccc}
# \pi & 0 & 0 & 2 \pi & 0 & 0 \\
# 0 & \pi & 0 & 0 & 2 \pi & 0 \\
# 0 & 0 & \pi & 0 & 0 & 2 \pi \\
# 0 & 0 & 0 & \pi & 0 & 0 \\
# 0 & 0 & 0 & 0 & \pi & 0 \\
# 0 & 0 & 0 & 0 & 0 & \pi
# \end{array}\right)
# $$

# %% [markdown]
# **Example**. We've already applied the definition of a tensor operator directly to compute the above operator applied to the tensor
#
# $$
# \zeta=\left(\begin{array}{c}
# 3 \\
# -6
# \end{array}\right) \otimes\left(\begin{array}{l}
# 1 \\
# 2 \\
# \pi
# \end{array}\right)+\left(\begin{array}{l}
# 1 \\
# 0
# \end{array}\right) \otimes\left(\begin{array}{l}
# 0 \\
# 1 \\
# 1
# \end{array}\right)=\left(\begin{array}{c}
# 3 \\
# 7 \\
# 1+3 \pi \\
# -6 \\
# -12 \\
# -6 \pi
# \end{array}\right)
# $$
#
# and found that, after reducing the result to a column vector,
#
# $$
# [A \otimes B] \zeta=\left(\begin{array}{c}
# -9 \pi \\
# -17 \pi \\
# \pi-9 \pi^{2} \\
# -6 \pi \\
# -12 \pi \\
# -6 \pi^{2}
# \end{array}\right)
# $$
#
# It now behooves us to do a sanity check. We must confirm that multiplication of $\zeta$ by the imputed matrix for $A \otimes B$ will produce the same result.
#
# $$
# [A \otimes B] \zeta=\left(\begin{array}{cccccc}
# \pi & 0 & 0 & 2 \pi & 0 & 0 \\
# 0 & \pi & 0 & 0 & 2 \pi & 0 \\
# 0 & 0 & \pi & 0 & 0 & 2 \pi \\
# 0 & 0 & 0 & \pi & 0 & 0 \\
# 0 & 0 & 0 & 0 & \pi & 0 \\
# 0 & 0 & 0 & 0 & 0 & \pi
# \end{array}\right)\left(\begin{array}{c}
# 3 \\
# 7 \\
# 1+3 \pi \\
# -6 \\
# -12 \\
# -6 \pi
# \end{array}\right)=?
# $$

# %% [markdown]
# > **Exercise**. Do the matrix multiplication, fill in the question mark, and see if it agrees with the column tensor above.

# %% [markdown]
# ### **10.3.3** The Matrix of a General Operator

# %% [markdown]
# As with the vectors in the product space (i.e., tensors), we can represent any *operator* on the product space as sum of no more than $(l m)^{2}$ separable operators, since there are that many elements in a tensor product matrix. The following exercise will make this clear.

# %% [markdown]
# > **Exercise**. Let the dimensions of our two component spaces be $l$ and $m$. Then pick two integers $p$ and $q$ in the range $0 \leq p, q < lm$. Show that the matrix
# $$
# P_{p q}
# $$
# which has a 1 in position $(p, q)$ and 0 in all other positions, is separable. Hint: You need to find an $l \times l$ matrix and an $m \times m$ matrix whose tensor product has 1 in the right position and 0 s everywhere else. Start by partitioning $P_{p q}$ into sub-matrices of size $m \times m$. Which sub-matrix does the lonely 1 fall into? Where in that $m \times m$ sub-matrix does that lonely 1 fall?

# %% [markdown]
# > **Exercise**. Show that the set of all $(l m)^{2}$ matrices
# $$
# \left\{P_{p q} \mid 0 \leq p, q < lm\right\}
# $$
# "spans" the set of linear transformations on $V \otimes W$.

# %% [markdown]
# ### **10.3.4** The Matrix of a General Operator

# %% [markdown]
# Before we move on to multi-qubit systems, here are a few more things for you may wish to ponder.
#
# > **Exercise**. Is the product of unitary operators unitary in the product space?
#
# > **Exercise**. Is the product of Hermitian operators Hermitian in the product space?
#
# > **Exercise**. Is the product of invertible operators invertible in the product space?
